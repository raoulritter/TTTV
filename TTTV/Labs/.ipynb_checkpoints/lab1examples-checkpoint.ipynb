# %%
# Python 3
# sudo apt-get install python3
# sudo apt-get install python3-pip
# Jupyter notebook (pip install jupyter)
# NLTK (pip install nltk)

# OF

# Gebruik anaconda 3 en je hebt alle packages gelijk
# Voer uit als admin
# Install for all users (en zorg dat hij hem ook in het path zet)

# Heb je dat niet gedaan?
# Voeg C:\Users\<Naam>\Anaconda3\bin toe aan de PATH variabele

# test op het eind: 
# >> jupyter notebook

# %%
JAVA

for(int x = 0: x < 10; x++) {
  // blabla
}

if( x < 10 || (x > 15 && x < 20)) {
  // blabla
}

public int printHello() {
  int output = 0;
  int actualOutput;
  actualOutput = output
  return actualOutput
;
}

Vector aList = new Vector;
# Out:
#   File "<ipython-input-2-f546683ade1d>", line 3
#     for(int x = 0: x < 10; x++) {
#             ^
# SyntaxError: invalid syntax

# %%
# variable declaren
a = 1
a = "string"
b = False
a = b

# loops
for x in range(10):
    pass

while b == True:
    pass


# Lists (bijna alles in python werkt hier mee)
llist = ["a", "c", "d"]
llist.append("b")

# Dictionaries
ddict = {}
ddict["aap"] = ["arm", "been"]
ddict["slang"] = ["staart", "hoofd"]

for x in ddict:
    print(x)
    for y in ddict[x]:
        print("---", y)

for x, y in ddict.items():
    print(x, y)
        
# Sets
sset = set()
sset.add(1)
sset.add(1)
sset.add(1)
sset.add(2)

if 2 in sset:
    pass

#lijst met unieke elementen?
llist = [1,2,3,4,5,5,5,3,3,3,3]
llist = list(set(llist))

# Tuples
ttuple = ("x", "y", "z")

for (x, y, z) in [("x", "y", "z"), ("x2", "y2", "z2")]:
    print(x, y, z)

# List comprehension (python gets crazy)
print([[x, y] for x in range(3) for y in range(2)])

# is de korte notatie voor:
llist = []
for x in range(3):
    for y in range(2):
        llist.append([x, y])
print(llist)
    
# Functies
def niceFuction():
    pass
# Out:
# aap
# --- arm
# --- been
# slang
# --- staart
# --- hoofd
# aap ['arm', 'been']
# slang ['staart', 'hoofd']
# x y z
# x2 y2 z2
# [[0, 0], [0, 1], [1, 0], [1, 1], [2, 0], [2, 1]]
# [[0, 0], [0, 1], [1, 0], [1, 1], [2, 0], [2, 1]]
